# %%
# kubernetes
# MLOps

# %%
# kubernetes 를 활용함 MSA(Micro Service Architecture)
# kubernetes 에서 쓰는 개념들을 설명할 것.

# %%
# 데이터 웨어하우스 - 정형 데이터만 탑재. 필요한 field 만 뽑아서 분석
# 데이터 레이크

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 데이터 엔지니어 - 카프카, 스파크(머신러닝에서도 매우 중요. 실시간 담보함)
# 스파크 분석을 했던 문서와 소스 제공. 실시간 데이터 받으면서 모델 만들고 계속 분석해
# 나가는 과정이 달려 있음.

# %%
# 프로젝트 할 때 꼭 서비스까지 할 것.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 우리가 만든 모델이 담긴 서비스를 쿠버에 pod 로 만들어서 놓고 올 때 마다 복제해서
# 할당해야 함. 쇼핑몰 데이터라고 해서 개인 데이터를 가지고 있는데 통합적 모델을 만들 수는
# 있지만 개인 특화 서비스는 불가함. 
# 보편적 모델을 할당하고, 다시 개인의 데이터를 가지고 학습시켜서 개인에 특화시켜서
# 개인 별 서비스를 하는 것이 좋음.
# 쿠버의 pod에 개인의 데이터를 연결해서 계속 학습시켜서 추천할 수 있도록 해줘야 함.

# %%
# 아마존 케이스 스터디, 넷플릭스 케이스 스터디

# %%
# kubernetes 기반의 오케스트레이션

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Docker
# 이제는 Containerd
# container 가 아니라 Virtual machine 이 더 격리성을 가짐.
# 쿠버에 비해서 가벼운 것이 도커 -> overhead 가 없다!
# 도커는 가상 머신이 아닌 컨테이너
# 쿠버가 나온 이유는 모든 작업을 자동화 하기 위함.

# %%
# kubernetes 의 장점
# 여러 호스트(서버)에 걸쳐 컨테이너를 자동관리
# 노태상 "nadream@gmail.com"
# 쿠버가 나온 이유는 중요한 이유는 자원을 제대로 쓰기 위함, 배포나 업데이트를 자동화.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# namespace 는 네이밍.
# volumne 이 저장소

# %%
# kubernetes 구성요소
# 마스터와 노드
# 오브젝트

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 오브젝트 스펙
# 베이직 오브젝트
# - pod(컨테이너들을 하나의 Pod 안에 둘 수 있음. 컨테이너화된 애플리케이션)
#    -> 하나의 서버에도 여러개의 pod 가능. Pod 간에 통신이 되어야 어떤 Pod를 쓸지를
#    -> 알 수 있음. 쿠버는 컨테이너가 아니라 pod에 ip가 할당되고 pod 안에 컨테이너는
#    -> 포트 넘버로 할당이 됨
# - service(pod로 올렸다고 바로 서비스x. 서비스라는 네이밍을 써서 올려야 함.)
# - volume(저장소)
# - namespace(네이밍 정책)

# %%
# 간단한 pod 를 정의한 오브젝트 스펙

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 직접 입력하지 말고 잘 되어있는 스펙 파일 가져와서 수정하는 것이 좋음.

# %%
# 서비스 타입 중 NodePort 를 기억

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# CNCF 에 있는 것들임.
# 색깔별로 통신 방식이 틀림
# 마스터의 구성요소
# 브라우저에서 서비스를 이용하려고 하면 API Server 한테 접속함.
# etcd 가 어디에 있는지 정보를 가지고 있음.
# Nodes 는 수십대가 있을 수 있음. etcd 가 각각의 노드에 대한 정보를 가짐
# 스케쥴러가 일의 우선순위를 정함
# 일은 노드가 함.
# RPC 는 사용자가 요청한 것을 대리요청하는 것. etcd 는 ip가 어디에 있고 이런 정보를
# 다 가지고 있음. etcd 는 local, 혹은 gitlab 에 둘 수 있음.
# local 에 두면 업데이트가 될 때 서비스가 오면 깨질 수 있음.

# %%
# protobuf 는 버퍼
# ingress 는 Nginx 로

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# TCP-IP 4 step
# OSI 7 layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# volume 은 저장소

# %%
# kubernetes 를 하려면 반드시 Helm 을 기억하는 것이 좋음

# %%
# yum
