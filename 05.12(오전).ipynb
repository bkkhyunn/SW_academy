# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x가 주어졌을 때 y가 최대가 되는 세타를 찼는 게 목적. 그래서 세타를 편미분 했더니 또 세타가 나옴.
그래서 세타를 추정해가는 방법으로 학습을 해야 함. 그러면 세타를 어떻게 찾을까? 결국 estimation 을 반복적으로 해야함. 그 백그라운드를 보자

# %%
미분값을 가지고 찾아가는 방법을 gradient method. 이 때 기울기를 증가/감소 방향으로 갈 수 있음. 위 예제는 주어진 확률이 최대화가 되어야 함.
MLE 를 해야하기 때문에 Likelihood 가 최대가 되어야 하기 때문에 기울기를 증가하는 방향으로 가야 함. 실제값 - 예측값인 에러가 최소화 되려면
gradient 가 최소가 되는 지점을 찾아가야 함.

# %%
Taylor Expansion - 테일러 급수

테일러 급수는 어떤 함수의 표현식. 무한합의 항. 어떤 무한합? 특정 점에서 함수가 미분이 가능할 때, 이게 무한합의 항으로 근사.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
미분식이 여러개가 있으면 됨. 이걸 가지고 gradient method 를 만들어 볼 것.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
특정점에서 미분계수 이용해서 나머지 애들 생략해서 f(x)를 만들어낼 것. h를 작은 값으로 가면 나머지를 무시할 수 있어서 수렴함.
그래서 learning rate를 작게 주는 이유임.

다음 스텝값과 초기값의 차이를 초기값의 미분값에 h라는 아주 작은 learning rate 인 h를 곱하고 방향을 결정하는 유닛 벡터u 를 곱해줌

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
실제 logisitic func 에 근사하면서 해를 찾아가는 방법을 gradient ascent 로 접근.
