# %% [markdown]
# ![image.png](attachment:image.png)

# %%
어떻게 수집할 것인가 아니면 기존의 수집된 것을 활용할 것인가?

-> 수집을 꼭 해야하는 것은,
fine tuning 하는 팀들. 남이 만든 모델을 가져와서 우리한테 맞추는 것, 큰 모델을 내 목
적에 맞춰서 줄이는 것 downstream 모델을 활용하는 팀들은 자신만의 데이터가 꼭 필요함.

# %%
그런데 그 데이터들을 어떻게 전처리?
사실 전처리 하기 전에 데이터에 대한 분석도 필요함.
분석을 해야 전처리를 할 수가 있기 때문에. 즉, 전처리만 필요한 게 아니라 데이터가 분석을
통해서 좀 부족한 것 같다. 기존에 비해서 특정 클래스의 개수가 부족할 수가 있다. 골치아픈
문제임. 따라서 데이터 증강도 필요할 수 있음.

# %%
의외로 데이터 자체를 분석하는 데에도 시간이 많이 걸림. 이 분석을 하기 위해서 우리가 이번
주에 다 못해도 최종 발표 때 까지는 다 해야함. 데이터는 계속 바뀜.
어떤 전처리, 어떤 증강 모델 돌려보면서 결과 보면서 무한 반복해야 함.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
계속 무얼 바꿔가면서 설계하고 반복!. 데이터셋부터 시작해서 계속해서 반복해야 함.
우리는 시간관계상 반복 못할 경우가 많음. 이번주에 처음 해볼 설계가 굉장히 중요함.
설계만 잘해도, 설계가 잘되어 있다는 것은 시간만 있으면 완성도를 보장해줄 수 있음.

# %%
두번째 큰 주제로 던졌던 것은 시스템관점.

# %%
실제 시스템이라는 것은 우리 지능정보 소프트웨어 아카데미에서 시스템이 소프트웨어를 담당하고
있는 애. 시스템을 만든다는 것은 실서비스. 실제 서비스하기 위해서 엄청나게 많은 고려사항이
필요함.

# %%
예를 들어 사용자가 누구냐. 어떤 환경에서 사용할 것인가. 카메라를 가져다 쓴다고 하면 카메
라의 셋팅값도 이 환경에 필요함. cctv 라고 한다면 어떤 거리에서. 모델이 유연하면 유연할
수록 서비스가 괜찮을 것. 즉 모델이 유연하다는 것, multi-scale 이미지를 받는 모델.
그런데 카메라의 거리를 위치시키고 그 크기만 딱 본다고 하면 모델 만들기는 쉬울 것인데 서
비스의 유연함은 떨어짐. 어떤 환경에서 어떻게 사용할 것이다. 얘도 우리가 시간만 있으면 충분
히 잘할 수 있다는 가정을 가지고 할 것.
우리는 toy example, 잘 돌아가는 서비스 정도까지만. 프로토타입 정도까지만 하자.
시간만 있으면 충분히 만들수도 있음.

# %%
시스템을 시스템 구성도까지 그리면, 실서비스 흐름 구성도는 데이터 흐름도 들어감.

# %%
사용할 때 실제 어떤 환경에서 데이터를 얻으면, 모바일 환경일수도 있고 웹 환경일 수도 있는데
모바일이면 이 모델이 서버에 있는지 기기에 탑재되어 있는 것인지도 고려해야 함. 서버에 있
으면 이미지를 내 핸드폰에 들어왔을 때 서버에 전송될 것이고 중간에 서버가 있을 것이고
그 서버에 있는 데이터가 모델에 전달될 것이고 거기에 나와있는 결과값이 사용자한테 다시 전달
되어야 함. 이런 구조들. 그게 시스템 구성도임. 각각의 구성요소들.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
프로젝트 실제 다 못만드는 경우가 많음. 너희의 시간이 부족해서. 배우는 입장에서 다 만들기
힘들어서 "설계"를 잘하는 것이 중요하다!

# %%
cctv, 자율주행 정말 많이 들고오는 주제인데, 차 안에 설치. 졸음운전 디텍션 만든 팀이
있었는데 눈 깜빡임으로 디텍션함. 그걸 카메라를 어디에 달아야 하냐고 심사위원이 물어봄.
그러면 운전하는 사람들은 카메라 위치를 어디에 달아야지 내 눈의 움직임이 찍힐 지 앎. 그러면
유리창 어디엔가 혹은 대시보드에 찍혀야 함. 그 각도 때문에 안나옴. 학습한 데이터와 실제
사용환경이 달라서. 이걸로 공격을 완전 받았음. 실서비스는 100프로 다 못 만들어도 됨.
이런 고려사항을 안하면 굉장히 많이 공격받음.

1등한 팀은 모든 구성구성 요소에 이런 문제상황들, 문제상황들 정확하게 정의가 되어 있을 것
인데, 해결하고자 하는 문제상황에 대한 준비가 철저히 되어 있어야 함.

# %%
저번시간 이어서 계속 수업
# Out:
#   Cell In[1], line 1
#     저번시간 이어서 계속 수업
#          ^
# SyntaxError: invalid syntax

# %%
모델 선택이라는 내용과 새로운 모델 개발했다는 내용 다 있음.
논문을 볼 때마다 느끼는 점은 나 말고 다른 논문들을 비교했을 것. 기본적으로 3~4개 정도.
좋은 논문은 보통 10개 이상 다른 모델과 비교함. 그 모델이 내 특정 이슈의 문제점을 해결할
수 있었다면 논문 안 나올 것. 내 특정 목적에 맞지 않기 때문에 선택할 수 없다. 그래서 특
정 문제를 해결하기 위한 새로운 모델을 개발했을 것.

# %%
우리가 본 대부분의 논문 대부분은 벤치마킹 데이터 셋을 사용함. 벤치마킹 데이터의 성능만
고려한 논문이 많을 것. 간혹 실제 서비스에 관련된 논문들은 precision, recall, 1종/
2종 오류도 고려했을 것. 모델에 대해서 설명할 때 그런 내용이 들어가 있어야 함. 왜 이런
모델을 만들었는지에 대한 근거를 제시해줘야 함. 근거를 제시하기 위해서는 목적이 정확할 필요
가 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
모델을 만드는 이유가 문제점을 해결하기 위해서. 목표가 있을 것. 보통 서비스를 하기 때문에
목표가 여러 개일 것. 목표가 여러개 있기 때문에 모델이 보통 어떤 식? 한단계가 있는 1sta-
ge 보다는 Multi-stage 가 될 것. 논문에는 1stage 가 좋지만 머신러닝 특징상 adHoc
이라고 함. 모델들은 특정 목적에만 잘됨. 여러개 범용적으로 잘되는 One stage 모델은 거의
없음.

# %%
1번에 대한 해결책 방법론 + 2번에 대한 해결책 방법론 + 3번에 대한 해결책 방법론
이 동네 사람들은 제일 싫어하는 것 중에 한개가 reinvent the wheel. 만들지 말고
가져다 써도 된다!

# %%
SOTA 는 1, 2, 3에 대해 각각을 해결한 것이지, 1,2,3 전체를 다 해결한 서비스 모델은
없을 것. 논문은 서비스보다는 알고리즘에 초점을 맞췄기 때문. 이런 것들은 오히려 특허에 많
음. 그래서 특허도 조사시켰던 것.

# %%
1, 2, 3을 완전히 처음부터 우리가 만들 수 없고 가져다 쓰는 사람이 더 훌륭함. 그런데 내 
목적에 맞지도 않는데 가져다 쓰는 것은 별로 안 좋음.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
또 하나 논류의 오류 중에서 결합의 오류라고 있음.
결합의 오류/분할의 오류
=> A, B, C가 잘하는 거 결합시켜 봤더니 잘하는 게 아님. 각각 잘한다고 해서 합쳐서
잘하지는 못함.
어떤 특정 팀이 최강이라고 해서 각 개인이 최강이라고 할 수 없는 것과 마찬가지.

# %%
네이버 자료에서 말하는 목적은 모바일 서비스를 위한 가벼운 이미지 인식/검출용 딥러닝 모델
설계. 모바일 서비스를 하기 위해서는 모델 크기가 작아야 함.
모델 크기가 작으면 내 핸드폰에 탑재할 수 있기 때문에, 서버단이 필요없음. 통신에 자유로울
수 있다는 것. 모바일 서비스를 하기 위해서 가볍다는 내용 주목.

# %%
모바일 서비스도 무거운 걸 돌리는 것도 가능함. object classification, detection
에 다 사용할 수 있는 백본 자체를 개발하겠다는 것!

# %%
그래서 네이버에서도 기존에 나와있는 이미지 인식/검출용 모델을 많이 참고함.
최신 가벼운 모델의 장단점을 다 분석함. 기존 논문들이 특정 환경에서 했기 때문에 논문만큼
성능이 나오지 않음.
우리와 똑같은 과정. 논문 보고 남의 것을 돌려봄. 남의 것 가져오는 것 굉장히 짜증남. 그 사
람들이 개발했던 세팅도 맞춰줘야 함.
그래서 네이버도 빡침. 그런데 기존 것이 좋으면 내 것을 새로 만들 필요가 없으니 성능을 꼭
재현해야 함. 그냥 가져다 쓰면 되는데 새로 만들기 위해서 재현함. 논문대로 세팅했는데 안되
어서 다른 세팅으로 동일 결과를 얻을 수 있도록 트레이닝 세팅 스터디를 함.

# %%
그래서 숨겨진 업계의 비밀 때문이라고 생각하고 옵티마이저, 학습률 에포크 수 등등 싹 바꿔보
니 어느정도 성능이 나옴. 네이버도 끝없이 공부하고 있음을 알 수 있음.

# %%
모바일 넷은 파인튜닝 잘 안됨. 즉 모바일용 백본을 만들기 위해서 네이버는 목표를 잡았는데
별로 안 좋았음. 실제 서비스! 우리가 하는 것도 실제 서비스임.

# %%
backbone 을 만들 때 fine tuning 잘 되면 좋은 것?
남이 만든 논문에 있는 거 그대로 쓰려 했더니 fine tuning 안되는 경우가 있음.
모바일 환경에서 쓸거라 모델 크기도 작아야 하고 고려할 사항들이 정말 많음.

# %%
각각의 단계별로 고려해야할 것이 바로 프로젝트의 완성도!

# %%
세팅 고려도 잘 해야함. 실제 서비스 이슈!

# %%
Flops 에 대해서도 스터디를 해보자! 모바일에 서비스 만들 팀들 몇 팀 있음. 성능에는
Accuracy, precision/recall(1/2오류) : 우리 상황, 우리 목적에 따라서 고려를
해야 함.

# %%
공부를 하면서 그 근거를 대면서 계획을 잘 짜면 좋음. 부족한 시간은 잠 덜자고 밥 빨리.
시간을 만들어내서 공부해라!

# %%
실제 성능은 좋은데 backbone 으로서의 성능은 별로 안좋다!
NAS(Network Architecture Search) - 강화학습
강화학습의 장점은 그 환경에 특별히 상호작용 하기 때문에 다른 머신러닝 모델들에 비해서 범
용성이 훨씬 떨어짐. 특정 환경에서만 잘 돌아감. 2019년에는 강화학습을 적용시키는 것이
유행이었음. 강화학습 기반으로 만들어서 ImageNet 데이터 대회에서나 성능이 좋지 다른 범용
적 상황에서는 성능이 좋을리가 없음. (강화학습의 문제점)

# %%
우리 시스템의 목적을 정확히 파악해야 함. 세부적인 상황 자체에 대한 목적. 그 설계는 우리가
해오면 선생님들이 목요일 이후부터 피드백을 해주실 것. 그래서 오늘 수업은 여기까지.
